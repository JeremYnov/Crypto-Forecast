# %%
import pandas as pd
from datetime import datetime
from time import sleep
import os

data = pd.read_csv('dataset/bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv')

# %%
df=data.dropna()

# %%
df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
df['Date'] = pd.Series(pd.to_datetime(df['Timestamp']).dt.date, index=df.index)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Timestamp')
# Out:
# C:\Users\jerem\AppData\Local\Temp/ipykernel_17668/1016402620.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Timestamp'] = pd.to_datetime(df['Timestamp'], unit='s')
# C:\Users\jerem\AppData\Local\Temp/ipykernel_17668/1016402620.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.Series(pd.to_datetime(df['Timestamp']).dt.date, index=df.index)
# C:\Users\jerem\AppData\Local\Temp/ipykernel_17668/1016402620.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])
#                   Timestamp      Open      High       Low     Close  \
# 0       2011-12-31 07:52:00      4.39      4.39      4.39      4.39
# 478     2011-12-31 15:50:00      4.39      4.39      4.39      4.39
# 547     2011-12-31 16:59:00      4.50      4.57      4.50      4.57
# 548     2011-12-31 17:00:00      4.58      4.58      4.58      4.58
# 1224    2012-01-01 04:16:00      4.58      4.58      4.58      4.58
# ...                     ...       ...       ...       ...       ...
# 4857372 2021-03-30 23:56:00  58714.31  58714.31  58686.00  58686.00
# 4857373 2021-03-30 23:57:00  58683.97  58693.43  58683.97  58685.81
# 4857374 2021-03-30 23:58:00  58693.43  58723.84  58693.43  58723.84
# 4857375 2021-03-30 23:59:00  58742.18  58770.38  58742.18  58760.59
# 4857376 2021-03-31 00:00:00  58767.75  58778.18  58755.97  58778.18
#
#          Volume_(BTC)  Volume_(Currency)  Weighted_Price       Date
# 0            0.455581           2.000000        4.390000 2011-12-31
# 478         48.000000         210.720000        4.390000 2011-12-31
# 547         37.862297         171.380338        4.526411 2011-12-31
# 548          9.000000          41.220000        4.580000 2011-12-31
# 1224         1.502000           6.879160        4.580000 2012-01-01
# ...               ...                ...             ...        ...
# 4857372      1.384487       81259.372187    58692.753339 2021-03-30
# 4857373      7.294848      428158.146640    58693.226508 2021-03-30
# 4857374      1.705682      100117.070370    58696.198496 2021-03-30
# 4857375      0.720415       42332.958633    58761.866202 2021-03-30
# 4857376      2.712831      159417.751000    58764.349363 2021-03-31
#
# [3613769 rows x 9 columns]

# %%
# df_unique_date = df['Timestamp'].map(pd.Timestamp.date).unique()

# %%
previousDate = df['Date'][0]
for i in df.index:
    newdf = df[df["Date"] == df["Date"][i]]
    if previousDate != df["Date"][i]:
        # Leaf directory
        directory = str(df["Date"][i]).split(' ')[0]
        newdf.to_csv("dataset/{}.csv".format(directory))
        previousDate =  df["Date"][i]
        # Parent Directories
        # parent_dir = "dataset"
        # Path
        # path = os.path.join(parent_dir, directory)
        # Create the directory
        # os.makedirs(path)
        # print("Directory '%s' created" %directory)
    else :
        print('Same Date')
# Out:
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# Same Date
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17668/3001780470.py in <module>
#       5         # Leaf directory
#       6         directory = str(df["Date"][i]).split(' ')[0]
# ----> 7         newdf.to_csv("dataset/{}.csv".format(directory))
#       8         previousDate =  df["Date"][i]
#       9         # Parent Directories
#
# c:\Users\jerem\Bureau\Crypto-Forecast\venv\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# c:\Users\jerem\Bureau\Crypto-Forecast\venv\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# c:\Users\jerem\Bureau\Crypto-Forecast\venv\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# c:\Users\jerem\Bureau\Crypto-Forecast\venv\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# ~\AppData\Local\Programs\Python\Python38\lib\codecs.py in __init__(self, errors)
#     184     remembers the state of the encoding process between calls to encode().
#     185     """
# --> 186     def __init__(self, errors='strict'):
#     187         """
#     188         Creates an IncrementalEncoder instance.
#
# KeyboardInterrupt:
